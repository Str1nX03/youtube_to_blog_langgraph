# %%
from src.utils import get_llm

llm = get_llm()
prompt = "What is the name of the creator of Python?"
response = llm.invoke(prompt)

# %%
print(response.content)
# Out:
# The creator of the Python programming language is Guido van Rossum. He is a Dutch computer programmer who started working on Python in the late 1980s and released the first version in 1991.

# %%
from src.agents.video_analyzer import YoutubeAnalyzeAgent

youtube_analyzer_agent = YoutubeAnalyzeAgent()

video_url = "https://youtu.be/SY_jMUantvw?si=TToHB90kronFEyZq"
response = youtube_analyzer_agent.run(video_url)

# %%
print(response["transcript"])

# %%
print(response["analysis"])

# %%
summary = """

**Structured Summary**

1. **Main Topic**: The video discusses the top 30 new open-world games of 2026, highlighting their features, release dates, and expectations.

2. **Key Points**:
* The video covers a range of open-world games, including Fortza Horizon 6, Fable, Chronicles Medieval, and Alahest.
* Some games, like Mortal Shell 2 and Assassin's Creed 4: Black Flag Reync, are expected to be significant releases in 2026.
* The video also mentions games with unique features, such as Solar Punk's intuitive building mechanics and Crimson Desert's complex combat system.
* Some games, like Subnotica 2 and Chrono Odyssey, have uncertain release dates or are still in development.
* The video highlights the diversity of open-world games, from survival crafting to action RPGs.

3. **The tone of the video**: The tone is informative, enthusiastic, and slightly casual. The host, Falcon, seems excited to share their knowledge of the upcoming games and provides a balanced view of each game's potential.

4. **Important keywords**: 
* Open-world games
* 2026 releases
* Fortza Horizon 6
* Fable
* Chronicles Medieval
* Alahest
* Mortal Shell 2
* Assassin's Creed 4: Black Flag Reync
* Solar Punk
* Crimson Desert
* Subnotica 2
* Chrono Odyssey
* Survival crafting
* Action RPGs
* Open-world sandbox
* Player agency
* Game development
* Release dates

"""

# %%
from src.agents.researcher import ResearchAgent

research_agent = ResearchAgent()

response = research_agent.run(summary)
# Out:
# [ 2026-02-02 13:20:50,462 ] root - INFO - Getting LLM
# [ 2026-02-02 13:20:51,399 ] root - INFO - LLM retrieved successfully
# [ 2026-02-02 13:20:51,407 ] root - INFO - Generating search queries based on video analysis...
# [ 2026-02-02 13:20:51,772 ] httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# [ 2026-02-02 13:20:51,813 ] root - INFO - Executing 3 search queries...
# [ 2026-02-02 13:20:51,814 ] root - INFO - Searching web for: 2026 open-world games release dates
# [ 2026-02-02 13:20:52,597 ] ddgs.ddgs - INFO - Error in engine grokipedia: DDGSException("RuntimeError: RuntimeError('error sending request for url (https://wt.wikipedia.org/w/api.php?action=opensearch&profile=fuzzy&limit=1&search=2026%20open-world%20games%20release%20dates): client error (Connect)\\n\\nCaused by:\\n    0: client error (Connect)\\n    1: dns error: No such host is known. (os error 11001)\\n    2: No such host is known. (os error 11001)')")
# ...

# %%
print(response["research_summary"])
# Out:
# External Research Findings:
#
# --- Results for: 2026 open-world games release dates ---
# ...

# %%
research_summary = """

External Research Findings:

--- Results for: 2026 open-world games release dates ---
While 2025 had a lot of stellar releases , 2026 is shaping up to be an even better year for gaming, especially when it comes to open-world games . From long-awaited releases that are finally arriving to games that are poised to take the genre in a new direction, these are the open-world games slated to arrive in 2026 and beyond. Rounding up all the upcoming 2026 games we're watching for PC release dates or launch windows in one handy calendar. 2026 Video Game Release Schedule by Game Informer Editorial on Jan 02, 2026 at 03:00 PM If you're wondering what games are coming up in 2026 , we've put them all in one convenient location. This list will be continually updated to act as a living, breathing schedule as new dates are announced, titles are delayed, and big reveals happen. What are the Best New Upcoming Open World Games of 2026 ? We break it down here for you in our list! Check it out! 2026 Upcoming Games Release Schedule These games are releasing across platforms like Xbox Series X|S, PS5, Switch 2, PC, and more in 2026 .

--- Results for: Fortza Horizon 6 and Fable latest updates ---
A massive Fortza Horizon 5, an update on Xbox One and Xbox One, comes with patches to reveal everything developer Playground Games has updated ... Xbox Developer Direct airs on 22 January and indy100 is live-blogging all the latest news including Fable and Forza Horizon 6 . Get the latest updates and release dates for Fable's new adventure and Forza Horizon 6's Japan map, as revealed at Xbox Developer Direct 2026. Xbox Developer_Direct News: " Fable ," "Forza Horizon 6 ," "Beast of Reincarnation" Updates + Surprise Double Fine Reveal Today's Xbox Developer_Direct kicked off a massive 2026 for Xbox, with deep dives into some of the year's most anticipated games, straight from the teams building them. Microsoft recently did their latest Xbox Developer_Direct event with the 2026 edition giving us a new look at multiple games and new release dates.

--- Results for: Mortal Shell 2 and Assassin's Creed 4: Black Flag Reync confirmed features ---
Jan 21, 2026 · A new tidal wave of posts across social media signals fans' excitement over the Assassin's Creed 4 : Black Flag remake, making it appear to be one of the most highly anticipated games of early 2026. Dec 9, 2025 · Despite years of internal leaks, fan speculation and even hints from the original game's lead actor, Ubisoft still has yet to officially confirm its Black Flag remake exists. Dec 14, 2025 · Ubisoft officially confirms Assassin ’ s Creed : Black Flag Resynced , the long-awaited remake of its beloved pirate adventure that had more leaks than a sunken ship. The game targets release before March 31, 2026, bringing massive visual upgrades and gameplay overhauls to the 2013 original. Dec 9, 2025 · Ubisoft hasn't actually announced the game, but has confirmed that remakes of older games in the series are in the works, and we've elsewhere seen a number of hints that one of them could be... Dec 1, 2025 · Despite endless rumours over recent years, the highly anticipated Assassin ’ s Creed IV : Black Flag remake has not been officially announced at the time of writing.

"""

# %%
from src.agents.video_analyzer import YoutubeAnalyzeAgent
from src.agents.researcher import ResearchAgent

youtube_analyzer_agent = YoutubeAnalyzeAgent()
research_agent = ResearchAgent()

video_url = "https://youtu.be/SY_jMUantvw?si=TToHB90kronFEyZq"
response = youtube_analyzer_agent.run(video_url)
video_summary = response["analysis"]
response = research_agent.run(video_summary)
research_summary = response["research_summary"]
# Out:
# [ 2026-02-03 14:09:25,600 ] root - INFO - Getting LLM
# [ 2026-02-03 14:09:26,326 ] root - INFO - LLM retrieved successfully
# [ 2026-02-03 14:09:26,333 ] root - INFO - Getting LLM
# [ 2026-02-03 14:09:27,048 ] root - INFO - LLM retrieved successfully
# [ 2026-02-03 14:09:31,159 ] httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# [ 2026-02-03 14:09:31,593 ] httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"
# ...

# %%
print(research_summary)
# Out:
# External Research Findings:
#
# --- Results for: latest updates on Forza Horizon 6 release date and gameplay features ---
# ...

# %%
print(video_summary)
# Out:
# Here is the structured summary of the YouTube video transcript:
#
# **1. Main Topic**
# The main topic of the video is the top 30 new open-world games of 2026, with the host discussing and ranking various upcoming games in the open-world genre.
#
# **2. Key Points**
# * The video discusses 20 open-world games, including Forza Horizon 6, Fable, Chronicles Medieval, and others.
# * The host provides an overview of each game, including their features, release dates, and expectations.
# * Some games, such as Forza Horizon 6 and Crimson Desert, are expected to be excellent, while others, such as Subnautica 2, have uncertain futures due to development issues.
# * The host also mentions the trend of more focused open-world experiences and the potential for innovation in the genre.
#
# **3. The tone of the video**
# ...

# %%
from src.agents.blogger import BloggerAgent

blogger_agent = BloggerAgent()

response = blogger_agent.run(video_summary, research_summary)
blog_post = response["blog_post"]
# Out:
# [ 2026-02-03 14:17:25,514 ] root - INFO - Getting LLM
# [ 2026-02-03 14:17:26,262 ] root - INFO - LLM retrieved successfully
# [ 2026-02-03 14:17:28,671 ] httpx - INFO - HTTP Request: POST https://api.groq.com/openai/v1/chat/completions "HTTP/1.1 200 OK"

# %%
print(blog_post)
# Out:
# ### Get Ready for the Ultimate Gaming Experience: Top 30 New Open-World Games of 2026
# The world of gaming is about to get a whole lot bigger and more exciting! With the new year comes a slew of highly anticipated open-world games that promise to transport us to new dimensions, challenge our skills, and push the boundaries of innovation. In this article, we'll dive into the top 30 new open-world games of 2026, featuring the likes of Forza Horizon 6, Fable, and Crimson Desert. Buckle up, gamers, it's going to be a wild ride!
#
# ### The Open-World Revolution: What to Expect
# ...
